# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title price  \
# 0               PlayStation 4 500GB Console (Renewed)
# 1              Sony Playstation PS4 1TB Black Console
# 2    PlayStation 4 Slim 1TB Console - Black (Renewed)
# 3   PlayStation 4 Slim 500GB Console [Discontinued...
# 4    PlayStation 4 Slim 1TB Console - Black (Renewed)
# 5        Sony PlayStation 2 Console - Black (Renewed)
# 6   Sony PlayStation 4 Slim Limited Edition 1TB Ga...
# 7            PlayStation 2 Slim Console PS2 (Renewed)
# 8   Playstation SONY 4, 500GB Slim System [CUH-221...
# 9             Playstation 2 Console - Black (Renewed)
# 10  PlayStation 4 Slim 1TB Console - Marvels Spide...
# 11  Sony PlayStation 4 Pro w/ Accessories, 1TB HDD...
# 12  Sony PlayStation 4 Slim Limited Edition 1TB Ga...
# 13  PlayStation 4 500GB Console [Old Model][Discon...
# 14  RPlay Play-Station 4 PS4 1TB Slim Edition Jet ...
# 15                     PlayStation 4 Slim 1TB Console
# 16  DualShock 4 Wireless Controller for PlayStatio...
# 17  PlayStation PS5 Console – God of War Ragnarök ...
# 18  DualShock 4 Wireless Controller for PlayStatio...
# 19  Logitech G Dual-Motor Feedback Driving Force G...
# 20  Playstation Sony 4, 500GB Slim System [CUH-221...
# 21                           NBA 2K23 - PlayStation 4
# 22         Sony Playstation 4 Dual Shock 4 Controller
# 23  TXTHcpo Wireless Controller for PS4 Remote, P4...
# 24  Wireless Controller Compatible with PS-4/PS-4 ...
# 25  DualShock 4 Wireless Controller for PlayStatio...
# 26  $110 PlayStation Plus – Wallet Funds [Digital ...
# 27  2 Pack Wireless Controller for Playstation 4, ...
# 28                    Sonic Frontiers - PlayStation 4
# 29  Aoidaruy Wireless Controller for PS4, Compatib...
# 30    $100 PlayStation Store Gift Card [Digital Code]
# 31  XISOGUU Wireless Controller Compatible with PS...
# 32  TXTHcpo Wireless Controller for PS4 Remote, P4...
# 33  Internal Cooling Fan for SONY PS4 CUH-12XX CUH...
# 34  Sony PlayStation 4 Slim Limited Edition 1TB Ga...
# 35             Sony Playstation PS4 1TB Black Console
# 36   PlayStation 4 Slim 1TB Console - Black (Renewed)
# 37  Sony PlayStation 4 Pro w/ Accessories, 1TB HDD...
# 38                     PlayStation 4 Slim 1TB Console
#
#                                          rating          reviews  \
# 0                            4.0 out of 5 stars      395 ratings
# 1                            4.7 out of 5 stars      988 ratings
# 2                            4.5 out of 5 stars    1,212 ratings
# 3                            4.5 out of 5 stars    1,252 ratings
# 4                            4.5 out of 5 stars    1,212 ratings
# 5                            4.3 out of 5 stars    1,108 ratings
# 6                            4.3 out of 5 stars    1,032 ratings
# 7                            4.2 out of 5 stars      946 ratings
# 8                            4.7 out of 5 stars      329 ratings
# 9                            4.2 out of 5 stars      311 ratings
# 10                           4.4 out of 5 stars      307 ratings
# 11                           4.1 out of 5 stars      465 ratings
# 12                           4.3 out of 5 stars    1,032 ratings
# 13                           4.6 out of 5 stars   13,645 ratings
# 14                           4.8 out of 5 stars        7 ratings
# 15                           4.7 out of 5 stars   15,361 ratings
# 16                           4.7 out of 5 stars  144,859 ratings
# 17                           4.8 out of 5 stars    5,497 ratings
# 18                           4.7 out of 5 stars  144,859 ratings
# 19                           4.7 out of 5 stars   16,029 ratings
# 20                           4.5 out of 5 stars      305 ratings
# 21                           4.7 out of 5 stars    1,226 ratings
# 22                           4.6 out of 5 stars    2,125 ratings
# 23                           3.8 out of 5 stars        4 ratings
# 24                           4.5 out of 5 stars       81 ratings
# 25                           4.7 out of 5 stars  144,859 ratings
# 26                           4.7 out of 5 stars  254,581 ratings
# 27                           4.2 out of 5 stars      517 ratings
# 28                           4.8 out of 5 stars      396 ratings
# 29  Previous page of related Sponsored Products
# 30                           4.7 out of 5 stars  254,581 ratings
# 31  Previous page of related Sponsored Products
# 32                           3.8 out of 5 stars        4 ratings
# 33                           4.2 out of 5 stars       51 ratings
# 34                           4.3 out of 5 stars    1,032 ratings
# 35                           4.7 out of 5 stars      988 ratings
# 36                           4.5 out of 5 stars    1,212 ratings
# 37                           4.1 out of 5 stars      465 ratings
# 38                           4.7 out of 5 stars   15,361 ratings
#
#                           availability
# 0                            In Stock.
# 1    Only 1 left in stock - order soon
# 2                            In stock.
# 3   Only 1 left in stock - order soon.
# 4                            In stock.
# 5   Only 1 left in stock - order soon.
# 6
# 7                            In stock.
# 8                            In Stock.
# 9   Only 3 left in stock - order soon.
# 10                           In Stock.
# 11                           In Stock.
# 12
# 13   Only 2 left in stock - order soon
# 14   Only 5 left in stock - order soon
# 15   Only 1 left in stock - order soon
# 16                            In Stock
# 17                            In Stock
# 18                            In Stock
# 19                            In Stock
# 20   Only 4 left in stock - order soon
# 21                            In Stock
# 22                            In Stock
# 23                            In Stock
# 24                            In Stock
# 25                            In Stock
# 26                       Available now
# 27                            In Stock
# 28                            In Stock
# 29                            In Stock
# 30                       Available now
# 31                            In Stock
# 32                            In Stock
# 33  Only 13 left in stock - order soon
# 34
# 35   Only 1 left in stock - order soon
# 36                           In stock.
# 37                           In Stock.
# 38   Only 1 left in stock - order soon
